# %% [markdown]
# # Image to Array

# %%
import numpy as np #nd array

# %%
import matplotlib.pyplot as plt  # visualization

# %%
from PIL import Image # pyton image library

# %%
image = Image.open(r'D:\NIT\1. NIT_Batches\1. MORNING BATCH\N_Batch -- 1030AM _ Sep26\1. Mar\25th, 26th - Numpy Introduction\poc - image anlaysis\pic.jpg')

# %%
image

# %%
type(image)

# %%
image_arr = np.asarray(image)
image_arr

# %%
plt.imshow(image_arr)
plt.show()

# %%
image_arr.shape

# %% [markdown]
# # Text to array

# %%
# Convert a sentence into an array of words

import numpy as np
text = "Generative AI is the future"
arr = np.array(text.split())
print(arr)
# Out:
# ['Generative' 'AI' 'is' 'the' 'future']

# %%
text1 = "Python"
arr1 = np.array(list(text1))
print(arr1)
# Out:
# ['P' 'y' 't' 'h' 'o' 'n']

# %%
print(type(arr1))
# Out:
# <class 'numpy.ndarray'>
