# %% [markdown]
# # Python Variable Introduction

# %%
v = 5 
v
# Out:
# 5

# %%
5 = v
# Out:
#   Cell In[3], line 1
#     5 = v
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
v = 5

# %%
v
# Out:
# 5

# %%
6
# Out:
# 6

# %% [markdown]
# # Rules to Define Python Variable

# %%
v1 = 45

# %%
V1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 V1
#
# NameError: name 'V1' is not defined

# %%
v1
# Out:
# 45

# %%
1v = 50
# Out:
#   Cell In[11], line 1
#     1v = 50
#     ^
# SyntaxError: invalid decimal literal

# %%
23a = 56
# Out:
#   Cell In[12], line 1
#     23a = 56
#      ^
# SyntaxError: invalid decimal literal

# %%
a23 = 56
a23
# Out:
# 56

# %%
nit@ = 45
# Out:
#   Cell In[14], line 1
#     nit@ = 45
#          ^
# SyntaxError: invalid syntax

# %%
nit_ = 45

# %%
nit_
# Out:
# 45

# %%
nit% = 78
nit%
# Out:
#   Cell In[17], line 1
#     nit% = 78
#          ^
# SyntaxError: invalid syntax

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
if = 56
# Out:
#   Cell In[20], line 1
#     if = 56
#        ^
# SyntaxError: invalid syntax

# %%
IF = 56

# %%
IF
# Out:
# 56

# %%
for = 67
for
# Out:
#   Cell In[23], line 1
#     for = 67
#         ^
# SyntaxError: invalid syntax

# %%
FOR = 67
FOR
# Out:
# 67

# %% [markdown]
# - 1st concept -- python variable
# - 2nd cocnept -- rules to defin python variable
# - 3rd concept -- introduction to function
# - 4th concept -- what is function argument & fun without argument
# - 5th concept -- variable & functin
# - 6th concept -- introduce to keyword

# %%
10 + 5
10 - 5
10 * 5
10 / 5 #float division 
10 // 5 #int division
# Out:
# 2

# %%
print(10 + 5)
print(10 - 5)
print(10 * 5)
print(10 / 5)
print(10 // 5)
# Out:
# 15
# 5
# 50
# 2.0
# 2

# %%
a = 56
print(a)
# Out:
# 56

# %% [markdown]
# # python variable = value
# # value == dataype

# %%
# integer 
a = 5
a
# Out:
# 5

# %%
type(a)
# Out:
# int

# %%
f  = 110.67
f
# Out:
# 110.67

# %%
type(f)
# Out:
# float

# %%
a = 5.5
type(a)
# Out:
# float

# %%
import sys
sys.version
# Out:
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# # integer ( value without decimal )

# %%
i = 45
i
# Out:
# 45

# %%
type(i)
# Out:
# int

# %% [markdown]
# #  float - value with decimal

# %%
f = 110.34
f
# Out:
# 110.34

# %%
type(f)
# Out:
# float

# %% [markdown]
# # bool

# %%
b = true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 b = true
#
# NameError: name 'true' is not defined

# %%
b = True
b
# Out:
# True

# %%
type(b)
# Out:
# bool

# %%
1b = False
1b
# Out:
#   Cell In[14], line 1
#     1b = False
#     ^
# SyntaxError: invalid decimal literal

# %%
b1 = False
b1
# Out:
# False

# %%
b2 = None 
b2

# %%
type(b2)
# Out:
# NoneType

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
print(True + True)
# Out:
# 2

# %%
print(True-False)
# Out:
# 1

# %%
print(False/True)
# Out:
# 0.0

# %%
print(False//True)
# Out:
# 0

# %%
print(True/False)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print(True/False)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # complex

# %%
c = 1 + 2j 
c
# Out:
# (1+2j)

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 1.0

# %%
c.imag
# Out:
# 2.0

# %%
d = 5 + 6j

# %%
print(c)
print(d)
# Out:
# (1+2j)
# (5+6j)

# %%
c + d
# Out:
# (6+8j)

# %%
c - d
# Out:
# (-4-4j)

# %% [markdown]
# # text = string

# %%
s = welcom to nareshit under expert prakash senapati
# Out:
#   Cell In[33], line 1
#     s = welcom to nareshit under expert prakash senapati
#                ^
# SyntaxError: invalid syntax

# %%
s = 'welcom to nareshit under expert prakash senapati'
s
# Out:
# 'welcom to nareshit under expert prakash senapati'

# %%
s1 = "welcom to nareshit under expert prakash senapati"
s1
# Out:
# 'welcom to nareshit under expert prakash senapati'

# %%
s2 = '''welcom to nareshit under expert prakash senapati'''
s2
# Out:
# 'welcom to nareshit under expert prakash senapati'

# %%
s3 = 'welcom to nareshit 
            under expert prakash senapati'
s3
# Out:
#   Cell In[40], line 1
#     s3 = 'welcom to nareshit
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s4 = "welcom to nareshit 
            under expert prakash senapati"
s4
# Out:
#   Cell In[41], line 1
#     s4 = "welcom to nareshit
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s5 = '''welcom to nareshit 
            under expert prakash senapati'''
s5
# Out:
# 'welcom to nareshit \n            under expert prakash senapati'

# %%
a1 = 25
b1 = 30 

print(id(a1))
print(id(b1))
# Out:
# 140714414352040
# 140714414352200

# %%
a2 = 26
b2 = 26

print(id(a2))
print(id(b2))
# Out:
# 140714414352072
# 140714414352072

# %% [markdown]
# # string indexing

# %%
si = 'hello'
si
# Out:
# 'hello'

# %%
si[0] #forward index
# Out:
# 'h'

# %%
si[-1]  #backward index
# Out:
# 'o'

# %%
si
# Out:
# 'hello'

# %%
si[-3]
# Out:
# 'l'

# %%
si
# Out:
# 'hello'

# %%
si[:]
# Out:
# 'hello'

# %%
si[2:5]
# Out:
# 'llo'

# %%
s5 = 'welcome'
s5
# Out:
# 'welcome'

# %%
s5[1:4]
# Out:
# 'elc'

# %%
s5 = 'welcome to nareshit'
s5
# Out:
# 'welcome to nareshit'

# %%
s5[1:7]
# Out:
# 'elcome'

# %%
s5[1:8]
# Out:
# 'elcome '

# %%
s5[:]
# Out:
# 'welcome to nareshit'

# %%
s5
# Out:
# 'welcome to nareshit'

# %%
s5[2:]
# Out:
# 'lcome to nareshit'

# %%
s5
# Out:
# 'welcome to nareshit'

# %%
s5[:10]
# Out:
# 'welcome to'

# %%
s5
# Out:
# 'welcome to nareshit'

# %%
s5[::1]
# Out:
# 'welcome to nareshit'

# %%
s5[::2]
# Out:
# 'wloet aeht'

# %%
s5
# Out:
# 'welcome to nareshit'

# %%
s5[::10]
# Out:
# 'w '

# %%
s5
# Out:
# 'welcome to nareshit'

# %%
s5[::-1]
# Out:
# 'tihseran ot emoclew'

# %%
s5
# Out:
# 'welcome to nareshit'

# %%
s5[::-5]
# Out:
# 'trtc'

# %%
s5
# Out:
# 'welcome to nareshit'

# %%
s5[1:20:10]
# Out:
# 'en'

# %%
s
# Out:
# 'welcom to nareshit under expert prakash senapati'

# %%
s6 = 'prakash'

# %%
print(s6[0])
print(s6[1])
print(s6[2])
# Out:
# p
# r
# a

# %%
for i in s6:
    print(i)
# Out:
# p
# r
# a
# k
# a
# s
# h
